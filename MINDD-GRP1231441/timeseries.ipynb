# %% [markdown]
# # Energy Consumption Forecast

# %% [markdown]
# - In this notebook, we will make **one-step** and **multi-step** forecast of electric consumption.
# - The dataset consists of **three years of hourly electricity load and temperature** records.
# - To make these predictions, we will use several kinds of **statistical**, **machine learning** and **deep learning** models. Then, we will compare their performances and select the best one.

# %% [markdown]
# ## Explaratory Data Analysis
# First, we will describe and visualize the dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neural_network import MLPRegressor
import xgboost as xgb


df = pd.read_excel('energy_demand.xlsx', sheet_name='energy_demand')
df
# Out:
#             Date  Hour    load          T
# 0     2012-01-01     0  2872.0  30.666667
# 1     2012-01-01     1  2698.0  32.000000
# 2     2012-01-01     2  2558.0  32.666667
# 3     2012-01-01     3  2444.0  30.000000
# 4     2012-01-01     4  2402.0  31.000000
# ...          ...   ...     ...        ...
# 26300 2014-12-31    20  4012.0  18.000000
# 26301 2014-12-31    21  3856.0  16.666667
# 26302 2014-12-31    22  3671.0  17.000000
# 26303 2014-12-31    23  3499.0  15.333333
# 26304 2014-12-31    24  3345.0  15.333333
#
# [26305 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26305 entries, 0 to 26304
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    26305 non-null  datetime64[ns]
#  1   Hour    26305 non-null  int64
#  2   load    26305 non-null  float64
#  3   T       26305 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1)
# memory usage: 822.2 KB

# %% [markdown]
# There are no missing values.
# We can rename the 'load' column to 'Load', so that the naming convention is the same of all columns and that we won't have to specify a custom label 'Load' in our graphs (for them to look good).

# %%
df.rename(columns={'load': 'Load'}, inplace=True)

# %% [markdown]
# We will set a partial index of Date + Hour and then visualize the data in a lineplot chronologically.

# %%
df = df.set_index(['Date', 'Hour'])
df.index
# Out:
# MultiIndex([('2012-01-01',  0),
#             ('2012-01-01',  1),
#             ('2012-01-01',  2),
#             ('2012-01-01',  3),
#             ('2012-01-01',  4),
#             ('2012-01-01',  5),
#             ('2012-01-01',  6),
#             ('2012-01-01',  7),
#             ('2012-01-01',  8),
#             ('2012-01-01',  9),
#             ...
#             ('2014-12-31', 15),
#             ('2014-12-31', 16),
#             ('2014-12-31', 17),
#             ('2014-12-31', 18),
#             ('2014-12-31', 19),
#             ('2014-12-31', 20),
#             ('2014-12-31', 21),
#             ('2014-12-31', 22),
#             ('2014-12-31', 23),
#             ('2014-12-31', 24)],
#            names=['Date', 'Hour'], length=26305)

# %%
df[10:40]
# Out:
#                    Load          T
# Date       Hour
# 2012-01-01 10    3105.0  33.333333
#            11    3174.0  36.666667
#            12    3180.0  40.333333
#            13    3184.0  43.666667
#            14    3147.0  43.333333
#            15    3122.0  45.000000
#            16    3137.0  44.666667
#            17    3486.0  43.333333
#            18    3717.0  41.666667
#            19    3659.0  41.333333
#            20    3513.0  41.666667
#            21    3344.0  42.666667
#            22    3129.0  43.333333
#            23    2873.0  44.333333
#            24    2639.0  44.000000
# 2012-01-02 1     2458.0  43.666667
#            2     2354.0  43.000000
#            3     2294.0  42.666667
#            4     2288.0  43.666667
#            5     2353.0  43.000000
#            6     2503.0  41.000000
#            7     2737.0  40.000000
#            8     2960.0  37.333333
#            9     3185.0  37.000000
#            10    3390.0  37.333333
#            11    3510.0  38.666667
#            12    3549.0  40.000000
#            13    3517.0  38.000000
#            14    3469.0  39.333333
#            15    3449.0  38.333333

# %%
df.loc[('2013-02-08', 7)]  # to showcase how to access a specific row using multi-index
# Out:
# Load    3701.000000
# T         12.666667
# Name: (2013-02-08 00:00:00, 7), dtype: float64

# %% [markdown]
# For visualization purposes, we can define new columns **Year, Month, Day**.

# %%
df['Year'] = df.index.get_level_values(0).year
df['Month'] = df.index.get_level_values(0).month
df['Day'] = df.index.get_level_values(0).day

# %% [markdown]
# Let's see how the **Energy Demand varies each hour**. We will also differentiate the lineplots by year, resulting in 3 lineplots, which we can compare and conclude if the Energy Demand varies year by year.

# %%
_, axes = plt.subplots(1, 2, figsize=(15, 5))

sns.lineplot(data=df, x='Hour', y='Load', hue='Year', errorbar=None, palette='bright', legend='full', ax=axes[0])\
    .set(title='Energy Demand in 2013, 2014, and 2015', ylabel='Load [kWh]');

sns.lineplot(data=df, x='Hour', y='Load', hue='Year', errorbar=None, palette='bright', legend='full', ax=axes[1])\
    .set(title='Energy Demand in 2013, 2014, and 2015', ylabel='Load [kWh]', ylim=(0, df['Load'].max()));

# %%
_, axes = plt.subplots(1, 2, figsize=(15, 5))
sns.lineplot(data=df, x='Month', y='Load', hue='Year',errorbar=None, palette='viridis', ax=axes[0])\
    .set(title='Energy Demand in 2013, 2014, and 2015', ylabel='Load [kWh]');
sns.lineplot(data=df, x='Month', y='Load', hue='Year',errorbar=None, palette='viridis', ax=axes[1])\
    .set(title='Energy Demand in 2013, 2014, and 2015', ylabel='Load [kWh]', ylim=(0, df['Load'].max()));

# %%
_, axes = plt.subplots(1, 2, figsize=(15, 5))
sns.lineplot(data=df, x='Day', y='Load', hue='Year', errorbar=None, palette='viridis', ax=axes[0])\
    .set(title='Energy Demand in 2013, 2014, and 2015', ylabel='Load [kWh]');
sns.lineplot(data=df, x='Day', y='Load', hue='Year', errorbar=None, palette='viridis', ax=axes[1])\
    .set(title='Energy Demand in 2013, 2014, and 2015', ylabel='Load [kWh]', ylim=(0, df['Load'].max()));

# %%
_, axes = plt.subplots(1, 2, figsize=(15, 5))
sns.lineplot(data=df, x='Date', y='Load', hue='Year', errorbar=None, palette='viridis', ax=axes[0])\
    .set(title='Energy Demand in 2013, 2014, and 2015', ylabel='Load [kWh]');
sns.lineplot(data=df, x='Date', y='Load', hue='Year', errorbar=None, palette='viridis', ax=axes[1])\
    .set(title='Energy Demand in 2013, 2014, and 2015', ylabel='Load [kWh]', ylim=(0, df['Load'].max()));

# %% [markdown]
# Also, from the visualizations, the data looks stationary. We can confirm that as following:

# %%
from statsmodels.tsa.stattools import adfuller

result = adfuller(df['Load'])
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
# Out:
# ADF Statistic: -10.406282
# p-value: 0.000000

# %% [markdown]
# What about **autocorrelation**? We can check if the data is a random walk (i.e. is not autocorrelated) or not by plotting the **autocorrelation function** for one day (24 hours).

# %%
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(df['Load'], lags=24);

# %% [markdown]
# The data is **highly autocorrelated**, meaning it is **not** a random walk.
# From the ACF plot we see that next day's value (from the same hour) is highly correlated to current value. This means that this value holds a lot of information for prediction.
# What about values from the same hours of next days? Let's check the graph.

# %%
plot_acf(df['Load'], lags=24*3 + 12);

# %% [markdown]
# The values from the same hours are still very correlated with the first value, but with every day, the correlation is slightly lower.
# Also, the autocorrelation coeficients **do not become abruptly non-significant** after lag q, meaning this **is not a MA(q) series**.
# Maybe it is a Autoregressive series. We can check if the coeficcients become abruptly non-significant after lag p.

# %%
from statsmodels.graphics.tsaplots import plot_pacf
plot_pacf(df['Load'], lags=24 * 2);

# %% [markdown]
# The coefficients **are** getting smaller after lag *p*, meaning it may be an autoregressive series.
# We can later try the Autoregressive model.

# %% [markdown]
# ### Summary
# - The **p-value is 0**, meaning the data is perfectly stationary. This is in agreement with our common sense.
# - **Scale is very important!** In the left sides, it would seem that the differences between hours/months/dates are bigger then they actually are, but that is because **the scale is misleading**. If we set the scale to start at 0 and end above the maximum value, then we get a much more trustworthy result.
# - By hour, the energy demand is the **lowest around 4AM** and **highest around 7PM**, which makes a lot of sense; at 4AM, everybody should be sleeping and not consuming energy and at 7PM, most of the household is at home, cooking dinner or using the appliances.
# - By month, **highest consumption is winter and summer months**, while during **spring and autumn it's lower**. I would argue this is because during winter months, the household uses heating a lot, while during summer months, they would use the AC.
# - During the days of the month, the energy demand stays at the same level.
# - The energy demand is **virtually the same in all three years**.

# %% [markdown]
# ## Data preparation
#
# To train our model, we first need to prepare our dataset to fit the models' requirements. To do that, we will:
# - Drop all the columns that are not neccessary (Day, Month, Year and Temperature)
# - Split the data into train and test set. The train set will be first 2 years and the test set the 3rd year.
# - Define the **sliding window** function, which will create lagged features.
# - Use the sliding windows function to create the lagged feautures, which are used by the model.

# %%
df.drop(columns=['Year', 'Month', 'Day', 'T'], inplace=True)

# %%
train = df[:'2013-12-31']
test = df['2014-01-01':]

assert len(train) + len(test) == len(df)
assert len(test) == 365 * 24  # 365 days * 24 hours
assert len(train) == 365 * 24 * 2 + 25  # it's 2 year + a leap day (24 hours) + first day of the dataset has 25 hours <0; 24>

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score
results = {}
def evaluate(y_test, y_pred, model_name):
    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    mape = round(mean_absolute_percentage_error(y_test, y_pred), 4)
    score = r2_score(y_test, y_pred)

    results[model_name] = [score, mae, mse, mape]

    print('Mean Absolute Error:', mae)
    print('Mean Squared Error:', mse)
    print(f'Mean Absolute Percentage Error: {mape * 100} %')
    print('Score:', score)

def plot_predicted_actual(y_test, y_pred, model_name):
    plt.figure(figsize=(15, 5))
    plt.xlabel('Times')
    plt.ylabel('Energy Demand')
    plt.title(f'Energy demand predictions versus actual values for year 2014 for {model_name}')
    plt.plot(y_test.values, label='Actual')
    plt.plot(y_pred, label='Predicted')
    plt.legend();

# %%
def slideWindow(df, window_in, horizon):
    d = df.values
    X, y = [], []
    idx = df.index[:-window_in]

    for start in range(len(df)-window_in):
        end = start + window_in
        out = end + horizon
        X.append(d[start:end].reshape(-1))
        y.append(d[end:out].ravel())
    
    cols_x = [f'x{i}' for i in range(1, window_in+1)]
    cols_y = [f'y{i}' for i in range(1, horizon+1)]
    df_xs = pd.DataFrame(X, index=idx, columns=cols_x)
    df_y = pd.DataFrame(y, index=idx, columns=cols_y)
    return pd.concat([df_xs, df_y], axis=1).dropna()

# %%
WIN_IN, HORIZON = 24*7, 1
train_shifted = slideWindow(train, WIN_IN, HORIZON)
test_shifted = slideWindow(test, WIN_IN, HORIZON)
X_train = train_shifted.iloc[:, :-HORIZON] 
y_train = train_shifted.iloc[:, -HORIZON:] 
X_test = test_shifted.iloc[:, :-HORIZON]
y_test = test_shifted.iloc[:, -HORIZON:]

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((17377, 168), (17377, 1), (8592, 168), (8592, 1))

# %% [markdown]
# ## Baseline Model

# %%
# Naive Baseline Model
y_pred_naive = X_test.iloc[:, -1]  # Use the last observed value as the prediction for all future time steps

print("\nEvaluation for Naive Baseline Model:")
evaluate(y_test, y_pred_naive, 'Naive Baseline Model')
# Out:
# Evaluation for Naive Baseline Model:
# Mean Absolute Error: 119.74767225325884
# Mean Squared Error: 26548.353526536313
# Mean Absolute Percentage Error: 3.74 %
# Score: 0.9103821778641711

# %% [markdown]
# ## Statistical models

# %% [markdown]
# ### Autoregressive model
# Since the ACF plot is not decaying to 0, we cannot use the moving average model.
# But the PACF is decaying to 0, so we will use the AR model.

# %%
from statsmodels.tsa.ar_model import AutoReg
df_stat = df.copy()
df_stat = df_stat.reset_index()
df_stat = df_stat.set_index('Date')
df_stat.index = pd.DatetimeIndex(df_stat.index).to_period('H')
train_stat = df_stat[:'2013-12-31']
test_stat = df_stat['2014-01-01':]
model = AutoReg(train_stat['Load'], lags=24)
result = model.fit()
y_pred = result.predict(start=25, end=len(train_stat)-1)
y_pred.dropna(inplace=True)

evaluate(train_stat['Load'][25:], y_pred, 'AR')
# Out:
# Mean Absolute Error: 34.78069249489046
# Mean Squared Error: 2467.6918608468654
# Mean Absolute Percentage Error: 1.06 %
# Score: 0.9924672208777867

# %% [markdown]
# The results seem very good. What about the combination of both MA and AR (ARMA)?
# We will choose the right combination of **p** and **q** based on the **Akaike information criteria** (the lower the better).

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
def optimize_ARMA(data, order_list) -> pd.DataFrame:
    results = []
    for order in order_list:
        try:
            model = SARIMAX(data, order=(order[0], 0, order[1]), simple_differencing=False).fit(disp=False)
        except:
            continue
        aic = model.aic
        results.append([order, aic])
    result_df = pd.DataFrame(results)   
    result_df.columns = ['(p,q)', 'AIC']
    #Sort in ascending order, lower AIC is better
    result_df = result_df.sort_values(by='AIC', ascending=True).reset_index(drop=True)
    return result_df

# %% [markdown]
# Just a note: Since our data is stationary, the d parameter is 0 (meaning we do not need to differentiate the series).

# %%
# ignore warnings
import warnings
warnings.filterwarnings('ignore')

results_df = optimize_ARMA(df_stat['Load'], [(p, q) for p in range(3) for q in range(3)])
results_df
# Out:
#     (p,q)            AIC
# 0  (2, 2)  306468.677085
# 1  (2, 1)  306893.219679
# 2  (1, 2)  309836.956699
# 3  (2, 0)  315047.609627
# 4  (1, 1)  318965.275697
# 5  (1, 0)  343881.604677
# 6  (0, 2)  439377.521359
# 7  (0, 1)  465715.622815
# 8  (0, 0)  501698.571331

# %% [markdown]
# The combination of **p=2** and **q=2** is the best.
# We will now perform **Residual analysis**. If the model captured all the predictive information from a dataset, the residuals of the model are **white noise**, meaning they **will be uncorrelated** and have **normal distribution**.

# %%
model = SARIMAX(train['Load'], order=(2,0,2), simple_differencing=False)

model_fit = model.fit(disp=False)
model_fit.plot_diagnostics(figsize=(10,8));

# %%
from statsmodels.stats.diagnostic import acorr_ljungbox
lags = np.arange(1,25)

test_results = acorr_ljungbox(model_fit.resid, lags=lags)
test_results['lb_pvalue']
# Out:
# 1      7.273281e-01
# 2      1.246791e-01
# 3      9.379255e-04
# 4      2.250115e-03
# 5      1.745622e-21
# 6      2.010603e-78
# 7      4.695962e-96
# 8     4.456535e-226
# 9     2.249916e-311
# 10     0.000000e+00
# 11     0.000000e+00
# 12     0.000000e+00
# 13     0.000000e+00
# 14     0.000000e+00
# 15     0.000000e+00
# 16     0.000000e+00
# 17     0.000000e+00
# 18     0.000000e+00
# 19     0.000000e+00
# 20     0.000000e+00
# 21     0.000000e+00
# 22     0.000000e+00
# 23     0.000000e+00
# 24     0.000000e+00
# Name: lb_pvalue, dtype: float64

# %% [markdown]
# All the p-values except the first 2 are less then 0.05. From this, we can conclude that the **residuals are not independent**, meaning it is not a good model for our data.

# %% [markdown]
# ## Machine learning models

# %%
machine_learning_models = {
    'Decision Tree': DecisionTreeRegressor(),
    'Random forest': RandomForestRegressor(),
    'Neural Network': MLPRegressor(),
    'XGBoost': xgb.XGBRegressor()
}

# %%
for name, model in machine_learning_models.items():
    estimator = model.fit(X_train, y_train)
    y_pred = estimator.predict(X_test)
    print(f"Evaluation for {name}:")
    evaluate(y_test, y_pred, name)
    plot_predicted_actual(y_test, y_pred, name)
    print('--------------------------------------')
# Out:
# Evaluation for Decision Tree:
# Mean Absolute Error: 52.233880353817504
# Mean Squared Error: 5662.049842877095
# Mean Absolute Percentage Error: 1.5699999999999998 %
# Score: 0.9808869286287013
# --------------------------------------
# Evaluation for Random forest:
# Mean Absolute Error: 31.229790502793293
# Mean Squared Error: 1946.5688059764896
# Mean Absolute Percentage Error: 0.9299999999999999 %
# Score: 0.9934290743546569
# --------------------------------------
# Evaluation for Neural Network:
# Mean Absolute Error: 56.95025030513123
# Mean Squared Error: 5099.921282480845
# Mean Absolute Percentage Error: 1.76 %
# Score: 0.9827844752050909
# --------------------------------------
# Evaluation for XGBoost:
# Mean Absolute Error: 34.97243671665866
# Mean Squared Error: 2228.600566351436
# Mean Absolute Percentage Error: 1.05 %
# Score: 0.9924770351966475
# --------------------------------------

# %% [markdown]
# # Deep learning models

# %% [markdown]
# _LSTM Model_

# %%
from keras.models import Sequential
from keras.layers import LSTM, GRU, Dense

# Reshape the input data for LSTM and GRU models
X_train_lstm = X_train.values.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test_lstm = X_test.values.reshape((X_test.shape[0], 1, X_test.shape[1]))

lstm_model = Sequential()
lstm_model.add(LSTM(50, activation='relu', input_shape=(1, X_train.shape[1])))
lstm_model.add(Dense(HORIZON))
lstm_model.compile(optimizer='adam', loss='mse')

lstm_model.fit(X_train_lstm, y_train, epochs=50, batch_size=32, verbose=1)
lstm_pred = lstm_model.predict(X_test_lstm)
evaluate(y_test, lstm_pred, 'LSTM')
# Out:
# WARNING:tensorflow:From c:\Users\rppin\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\Users\rppin\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\rppin\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/50
# WARNING:tensorflow:From c:\Users\rppin\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 544/544 [==============================] - 3s 2ms/step - loss: 220795.1562
# Epoch 2/50
# 544/544 [==============================] - 1s 2ms/step - loss: 28571.8945
# Epoch 3/50
# 544/544 [==============================] - 1s 2ms/step - loss: 22292.1055
# Epoch 4/50
# 544/544 [==============================] - 1s 2ms/step - loss: 19345.1992
# Epoch 5/50
# 544/544 [==============================] - 1s 2ms/step - loss: 17058.8574
# Epoch 6/50
# 544/544 [==============================] - 1s 2ms/step - loss: 14293.1338
# Epoch 7/50
# 544/544 [==============================] - 1s 2ms/step - loss: 12920.5801
# Epoch 8/50
# 544/544 [==============================] - 1s 2ms/step - loss: 12286.9111
# Epoch 9/50
# 544/544 [==============================] - 1s 2ms/step - loss: 11436.1973
# Epoch 10/50
# 544/544 [==============================] - 1s 2ms/step - loss: 9910.3525
# Epoch 11/50
# 544/544 [==============================] - 1s 2ms/step - loss: 9807.4316
# Epoch 12/50
# 544/544 [==============================] - 1s 2ms/step - loss: 9164.1191
# Epoch 13/50
# 544/544 [==============================] - 1s 2ms/step - loss: 8562.0645
# Epoch 14/50
# 544/544 [==============================] - 1s 2ms/step - loss: 7589.3813
# Epoch 15/50
# 544/544 [==============================] - 1s 2ms/step - loss: 7880.6899
# Epoch 16/50
# 544/544 [==============================] - 1s 2ms/step - loss: 8763.4951
# Epoch 17/50
# 544/544 [==============================] - 1s 2ms/step - loss: 7010.6992
# Epoch 18/50
# 544/544 [==============================] - 1s 2ms/step - loss: 6648.9155
# Epoch 19/50
# 544/544 [==============================] - 1s 2ms/step - loss: 6631.8940
# Epoch 20/50
# 544/544 [==============================] - 1s 2ms/step - loss: 6779.0688
# Epoch 21/50
# 544/544 [==============================] - 1s 2ms/step - loss: 5972.2466
# Epoch 22/50
# 544/544 [==============================] - 1s 2ms/step - loss: 6491.3828
# Epoch 23/50
# 544/544 [==============================] - 1s 2ms/step - loss: 6908.0977
# Epoch 24/50
# 544/544 [==============================] - 1s 2ms/step - loss: 5911.4365
# Epoch 25/50
# 544/544 [==============================] - 1s 2ms/step - loss: 5946.6865
# Epoch 26/50
# 544/544 [==============================] - 1s 2ms/step - loss: 5499.4824
# Epoch 27/50
# 544/544 [==============================] - 1s 2ms/step - loss: 6090.9263
# Epoch 28/50
# 544/544 [==============================] - 1s 2ms/step - loss: 5361.8003
# Epoch 29/50
# 544/544 [==============================] - 1s 2ms/step - loss: 5540.4541
# Epoch 30/50
# 544/544 [==============================] - 1s 2ms/step - loss: 4989.4307
# Epoch 31/50
# 544/544 [==============================] - 1s 2ms/step - loss: 5305.9771
# Epoch 32/50
# 544/544 [==============================] - 1s 2ms/step - loss: 5511.7373
# Epoch 33/50
# 544/544 [==============================] - 1s 2ms/step - loss: 5177.4897
# Epoch 34/50
# 544/544 [==============================] - 1s 2ms/step - loss: 5250.7026
# Epoch 35/50
# 544/544 [==============================] - 1s 2ms/step - loss: 5160.4775
# Epoch 36/50
# 544/544 [==============================] - 1s 2ms/step - loss: 6375.1484
# Epoch 37/50
# 544/544 [==============================] - 1s 2ms/step - loss: 4414.9458
# Epoch 38/50
# 544/544 [==============================] - 1s 2ms/step - loss: 4480.9922
# Epoch 39/50
# 544/544 [==============================] - 1s 2ms/step - loss: 4909.3970
# Epoch 40/50
# 544/544 [==============================] - 1s 2ms/step - loss: 4792.6353
# Epoch 41/50
# 544/544 [==============================] - 1s 2ms/step - loss: 4403.4575
# Epoch 42/50
# 544/544 [==============================] - 1s 2ms/step - loss: 4449.5488
# Epoch 43/50
# 544/544 [==============================] - 1s 2ms/step - loss: 4695.1421
# Epoch 44/50
# 544/544 [==============================] - 1s 2ms/step - loss: 4353.2466
# Epoch 45/50
# 544/544 [==============================] - 1s 2ms/step - loss: 4982.7373
# Epoch 46/50
# 544/544 [==============================] - 1s 2ms/step - loss: 4384.5278
# Epoch 47/50
# 544/544 [==============================] - 1s 2ms/step - loss: 4189.4033
# Epoch 48/50
# 544/544 [==============================] - 1s 2ms/step - loss: 4280.3032
# Epoch 49/50
# 544/544 [==============================] - 1s 2ms/step - loss: 4257.7642
# Epoch 50/50
# 544/544 [==============================] - 1s 2ms/step - loss: 4160.5425
# 269/269 [==============================] - 1s 1ms/step
# Mean Absolute Error: 53.17606843916398
# Mean Squared Error: 4548.8432836912125
# Mean Absolute Percentage Error: 1.6199999999999999 %
# Score: 0.9846447190062417

# %% [markdown]
# _GRU Model_

# %%
gru_model = Sequential()
gru_model.add(GRU(50, activation='relu', input_shape=(1, X_train.shape[1])))
gru_model.add(Dense(HORIZON))
gru_model.compile(optimizer='adam', loss='mse')

gru_model.fit(X_train_lstm, y_train, epochs=50, batch_size=32, verbose=1)

gru_pred = gru_model.predict(X_test_lstm)
evaluate(y_test, gru_pred, 'GRU')
# Out:
# Epoch 1/50
# 544/544 [==============================] - 2s 2ms/step - loss: 121454.1797
# Epoch 2/50
# 544/544 [==============================] - 1s 2ms/step - loss: 27138.0391
# Epoch 3/50
# 544/544 [==============================] - 1s 2ms/step - loss: 20866.8594
# Epoch 4/50
# 544/544 [==============================] - 1s 2ms/step - loss: 17660.8184
# Epoch 5/50
# 544/544 [==============================] - 1s 2ms/step - loss: 15197.0352
# Epoch 6/50
# 544/544 [==============================] - 1s 2ms/step - loss: 14025.0479
# Epoch 7/50
# 544/544 [==============================] - 1s 2ms/step - loss: 12740.0879
# Epoch 8/50
# 544/544 [==============================] - 1s 2ms/step - loss: 11832.7158
# Epoch 9/50
# 544/544 [==============================] - 1s 2ms/step - loss: 11176.4033
# Epoch 10/50
# 544/544 [==============================] - 1s 2ms/step - loss: 9562.7012
# Epoch 11/50
# 544/544 [==============================] - 1s 2ms/step - loss: 9968.9990
# Epoch 12/50
# 544/544 [==============================] - 1s 2ms/step - loss: 9378.3965
# Epoch 13/50
# 544/544 [==============================] - 1s 2ms/step - loss: 8190.4146
# Epoch 14/50
# 544/544 [==============================] - 1s 2ms/step - loss: 8207.7354
# Epoch 15/50
# 544/544 [==============================] - 1s 2ms/step - loss: 7853.8638
# Epoch 16/50
# 544/544 [==============================] - 1s 2ms/step - loss: 7056.7656
# Epoch 17/50
# 544/544 [==============================] - 1s 2ms/step - loss: 6937.2710
# Epoch 18/50
# 544/544 [==============================] - 1s 2ms/step - loss: 7085.8979
# Epoch 19/50
# 544/544 [==============================] - 1s 2ms/step - loss: 7226.1611
# Epoch 20/50
# 544/544 [==============================] - 1s 2ms/step - loss: 6780.0400
# Epoch 21/50
# 544/544 [==============================] - 1s 2ms/step - loss: 6323.3525
# Epoch 22/50
# 544/544 [==============================] - 1s 2ms/step - loss: 6279.8340
# Epoch 23/50
# 544/544 [==============================] - 1s 2ms/step - loss: 7804.2002
# Epoch 24/50
# 544/544 [==============================] - 1s 2ms/step - loss: 5964.0723
# Epoch 25/50
# 544/544 [==============================] - 1s 2ms/step - loss: 6080.9048
# Epoch 26/50
# 544/544 [==============================] - 1s 2ms/step - loss: 6167.1689
# Epoch 27/50
# 544/544 [==============================] - 1s 2ms/step - loss: 5797.9893
# Epoch 28/50
# 544/544 [==============================] - 1s 2ms/step - loss: 5721.0996
# Epoch 29/50
# 544/544 [==============================] - 1s 2ms/step - loss: 5465.1030
# Epoch 30/50
# 544/544 [==============================] - 1s 2ms/step - loss: 5888.4253
# Epoch 31/50
# 544/544 [==============================] - 1s 2ms/step - loss: 5469.5405
# Epoch 32/50
# 544/544 [==============================] - 1s 2ms/step - loss: 5232.9468
# Epoch 33/50
# 544/544 [==============================] - 1s 2ms/step - loss: 5135.4336
# Epoch 34/50
# 544/544 [==============================] - 1s 2ms/step - loss: 5988.7788
# Epoch 35/50
# 544/544 [==============================] - 1s 2ms/step - loss: 5104.1226
# Epoch 36/50
# 544/544 [==============================] - 1s 2ms/step - loss: 5152.3438
# Epoch 37/50
# 544/544 [==============================] - 1s 2ms/step - loss: 4890.1807
# Epoch 38/50
# 544/544 [==============================] - 1s 2ms/step - loss: 4959.9634
# Epoch 39/50
# 544/544 [==============================] - 1s 2ms/step - loss: 5325.6392
# Epoch 40/50
# 544/544 [==============================] - 1s 2ms/step - loss: 4503.6777
# Epoch 41/50
# 544/544 [==============================] - 1s 2ms/step - loss: 5043.2236
# Epoch 42/50
# 544/544 [==============================] - 1s 2ms/step - loss: 4933.2866
# Epoch 43/50
# 544/544 [==============================] - 1s 2ms/step - loss: 4870.2842
# Epoch 44/50
# 544/544 [==============================] - 1s 2ms/step - loss: 4511.5371
# Epoch 45/50
# 544/544 [==============================] - 1s 2ms/step - loss: 5129.4624
# Epoch 46/50
# 544/544 [==============================] - 1s 2ms/step - loss: 4235.1865
# Epoch 47/50
# 544/544 [==============================] - 1s 2ms/step - loss: 5159.8193
# Epoch 48/50
# 544/544 [==============================] - 1s 2ms/step - loss: 4481.7925
# Epoch 49/50
# 544/544 [==============================] - 1s 2ms/step - loss: 4251.7051
# Epoch 50/50
# 544/544 [==============================] - 1s 2ms/step - loss: 4599.7021
# 269/269 [==============================] - 1s 1ms/step
# Mean Absolute Error: 122.51770175813074
# Mean Squared Error: 17734.60807952298
# Mean Absolute Percentage Error: 3.81 %
# Score: 0.9401342553717801

# %% [markdown]
# ## Multi-step forecast

# %%
train_multistep = slideWindow(train, WIN_IN, 24)
test_multistep = slideWindow(test, WIN_IN, 24)
X_train = train_shifted.iloc[:, :-HORIZON] 
y_train = train_shifted.iloc[:, -HORIZON:] 
X_test = test_shifted.iloc[:, :-HORIZON]
y_test = test_shifted.iloc[:, -HORIZON:]

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((17377, 168), (17377, 1), (8592, 168), (8592, 1))

# %%
for name, model in machine_learning_models.items():
    estimator = model.fit(X_train, y_train)
    y_pred = estimator.predict(X_test)
    print(f"Evaluation for {name}:")
    evaluate(y_test, y_pred, name + '-MS')
    plot_predicted_actual(y_test, y_pred, name)
    print('--------------------------------------')
# Out:
# Evaluation for Decision Tree:
# Mean Absolute Error: 52.101315176908756
# Mean Squared Error: 5645.812761871508
# Mean Absolute Percentage Error: 1.5599999999999998 %
# Score: 0.9809417392532513
# --------------------------------------
# Evaluation for Random forest:
# Mean Absolute Error: 30.91510416666667
# Mean Squared Error: 1902.7399034945297
# Mean Absolute Percentage Error: 0.9199999999999999 %
# Score: 0.9935770251789183
# --------------------------------------
# Evaluation for Neural Network:
# Mean Absolute Error: 52.672893348984076
# Mean Squared Error: 4910.598910290085
# Mean Absolute Percentage Error: 1.6 %
# Score: 0.98342356036193
# --------------------------------------
# Evaluation for XGBoost:
# Mean Absolute Error: 34.97243671665866
# Mean Squared Error: 2228.600566351436
# Mean Absolute Percentage Error: 1.05 %
# Score: 0.9924770351966475
# --------------------------------------

# %%
#LSTM
#done to reduce processing time 
WIN_IN = 24  
HORIZON = 4  

train_data_lstm_ms = slideWindow(train, WIN_IN, HORIZON)
test_data_lstm_ms = slideWindow(test, WIN_IN, HORIZON)

X_train_lstm_ms = train_data_lstm_ms.iloc[:, :-HORIZON]
y_train_lstm_ms = train_data_lstm_ms.iloc[:, -HORIZON:]

X_test_lstm_ms = test_data_lstm_ms.iloc[:, :-HORIZON]
y_test_lstm_ms = test_data_lstm_ms.iloc[:, -HORIZON:]

X_train_lstm_ms = X_train_lstm_ms.values.reshape((X_train_lstm_ms.shape[0], 1, X_train_lstm_ms.shape[1]))
X_test_lstm_ms = X_test_lstm_ms.values.reshape((X_test_lstm_ms.shape[0], 1, X_test_lstm_ms.shape[1]))

lstm_model = Sequential()
lstm_model.add(LSTM(50, activation='relu', input_shape=(1, X_train_lstm_ms.shape[2])))
lstm_model.add(Dense(HORIZON))
lstm_model.compile(optimizer='adam', loss='mse')

lstm_model.fit(X_train_lstm_ms, y_train_lstm_ms.values, epochs=50, batch_size=32, verbose=1)

y_pred_lstm = lstm_model.predict(X_test_lstm_ms)

evaluate(y_test_lstm_ms.values, y_pred_lstm, 'LSTM-MS')
# Out:
# Epoch 1/50
# 548/548 [==============================] - 2s 2ms/step - loss: 654711.3125
# Epoch 2/50
# 548/548 [==============================] - 1s 2ms/step - loss: 117106.9219
# Epoch 3/50
# 548/548 [==============================] - 1s 2ms/step - loss: 64897.8281
# Epoch 4/50
# 548/548 [==============================] - 1s 2ms/step - loss: 50593.0703
# Epoch 5/50
# 548/548 [==============================] - 1s 2ms/step - loss: 41730.6953
# Epoch 6/50
# 548/548 [==============================] - 1s 2ms/step - loss: 35641.8633
# Epoch 7/50
# 548/548 [==============================] - 1s 2ms/step - loss: 32876.4375
# Epoch 8/50
# 548/548 [==============================] - 1s 2ms/step - loss: 31145.4219
# Epoch 9/50
# 548/548 [==============================] - 1s 2ms/step - loss: 29592.3750
# Epoch 10/50
# 548/548 [==============================] - 1s 2ms/step - loss: 28272.6777
# Epoch 11/50
# 548/548 [==============================] - 1s 2ms/step - loss: 27083.7871
# Epoch 12/50
# 548/548 [==============================] - 1s 2ms/step - loss: 25920.1270
# Epoch 13/50
# 548/548 [==============================] - 1s 2ms/step - loss: 24788.8965
# Epoch 14/50
# 548/548 [==============================] - 1s 2ms/step - loss: 23770.9395
# Epoch 15/50
# 548/548 [==============================] - 1s 2ms/step - loss: 22874.0820
# Epoch 16/50
# 548/548 [==============================] - 1s 2ms/step - loss: 22008.7070
# Epoch 17/50
# 548/548 [==============================] - 1s 2ms/step - loss: 21157.0723
# Epoch 18/50
# 548/548 [==============================] - 1s 2ms/step - loss: 20655.0762
# Epoch 19/50
# 548/548 [==============================] - 1s 2ms/step - loss: 20215.8203
# Epoch 20/50
# 548/548 [==============================] - 1s 2ms/step - loss: 19476.0117
# Epoch 21/50
# 548/548 [==============================] - 1s 2ms/step - loss: 19152.8672
# Epoch 22/50
# 548/548 [==============================] - 1s 2ms/step - loss: 18583.2773
# Epoch 23/50
# 548/548 [==============================] - 1s 2ms/step - loss: 18260.2285
# Epoch 24/50
# 548/548 [==============================] - 1s 2ms/step - loss: 17894.0410
# Epoch 25/50
# 548/548 [==============================] - 1s 2ms/step - loss: 17580.7441
# Epoch 26/50
# 548/548 [==============================] - 1s 2ms/step - loss: 17320.5762
# Epoch 27/50
# 548/548 [==============================] - 1s 2ms/step - loss: 17071.7109
# Epoch 28/50
# 548/548 [==============================] - 1s 2ms/step - loss: 16546.2051
# Epoch 29/50
# 548/548 [==============================] - 1s 2ms/step - loss: 16490.0918
# Epoch 30/50
# 548/548 [==============================] - 1s 2ms/step - loss: 16009.9678
# Epoch 31/50
# 548/548 [==============================] - 1s 2ms/step - loss: 15926.9355
# Epoch 32/50
# 548/548 [==============================] - 1s 2ms/step - loss: 15846.1963
# Epoch 33/50
# 548/548 [==============================] - 1s 2ms/step - loss: 15420.5840
# Epoch 34/50
# 548/548 [==============================] - 1s 2ms/step - loss: 15381.2920
# Epoch 35/50
# 548/548 [==============================] - 1s 2ms/step - loss: 15223.6982
# Epoch 36/50
# 548/548 [==============================] - 1s 2ms/step - loss: 15175.9668
# Epoch 37/50
# 548/548 [==============================] - 1s 2ms/step - loss: 14987.4404
# Epoch 38/50
# 548/548 [==============================] - 1s 2ms/step - loss: 14955.4551
# Epoch 39/50
# 548/548 [==============================] - 1s 2ms/step - loss: 14695.6143
# Epoch 40/50
# 548/548 [==============================] - 1s 2ms/step - loss: 14389.2314
# Epoch 41/50
# 548/548 [==============================] - 1s 2ms/step - loss: 14422.2432
# Epoch 42/50
# 548/548 [==============================] - 1s 2ms/step - loss: 14260.4365
# Epoch 43/50
# 548/548 [==============================] - 1s 2ms/step - loss: 14327.7803
# Epoch 44/50
# 548/548 [==============================] - 1s 2ms/step - loss: 14340.8105
# Epoch 45/50
# 548/548 [==============================] - 1s 2ms/step - loss: 13931.6240
# Epoch 46/50
# 548/548 [==============================] - 1s 2ms/step - loss: 13706.6846
# Epoch 47/50
# 548/548 [==============================] - 1s 2ms/step - loss: 13776.2891
# Epoch 48/50
# 548/548 [==============================] - 1s 2ms/step - loss: 13785.3799
# Epoch 49/50
# 548/548 [==============================] - 1s 2ms/step - loss: 13579.5928
# Epoch 50/50
# 548/548 [==============================] - 1s 2ms/step - loss: 13562.6338
# 273/273 [==============================] - 0s 1ms/step
# Mean Absolute Error: 85.2084966493775
# Mean Squared Error: 13626.203493792496
# Mean Absolute Percentage Error: 2.6100000000000003 %
# Score: 0.9546253683131964

# %%
#GRU
X_train_gru_ms = X_train_lstm_ms.reshape((X_train_lstm_ms.shape[0], X_train_lstm_ms.shape[1], X_train_lstm_ms.shape[2]))
X_test_gru_ms = X_test_lstm_ms.reshape((X_test_lstm_ms.shape[0], X_test_lstm_ms.shape[1], X_test_lstm_ms.shape[2]))

gru_model = Sequential()
gru_model.add(GRU(50, activation='relu', input_shape=(X_train_gru_ms.shape[1], X_train_gru_ms.shape[2])))
gru_model.add(Dense(HORIZON))
gru_model.compile(optimizer='adam', loss='mse')

gru_model.fit(X_train_gru_ms, y_train_lstm_ms.values, epochs=50, batch_size=32, verbose=1)

y_pred_gru = gru_model.predict(X_test_gru_ms)

evaluate(y_test_lstm_ms.values, y_pred_gru, 'GRU-MS')
# Out:
# Epoch 1/50
# 548/548 [==============================] - 2s 2ms/step - loss: 595068.1250
# Epoch 2/50
# 548/548 [==============================] - 1s 2ms/step - loss: 58934.5469
# Epoch 3/50
# 548/548 [==============================] - 1s 2ms/step - loss: 42120.4492
# Epoch 4/50
# 548/548 [==============================] - 1s 2ms/step - loss: 36408.5195
# Epoch 5/50
# 548/548 [==============================] - 1s 2ms/step - loss: 33346.5273
# Epoch 6/50
# 548/548 [==============================] - 1s 2ms/step - loss: 31026.5840
# Epoch 7/50
# 548/548 [==============================] - 1s 2ms/step - loss: 28720.4570
# Epoch 8/50
# 548/548 [==============================] - 1s 2ms/step - loss: 26693.7617
# Epoch 9/50
# 548/548 [==============================] - 1s 2ms/step - loss: 25196.0508
# Epoch 10/50
# 548/548 [==============================] - 1s 2ms/step - loss: 23549.1797
# Epoch 11/50
# 548/548 [==============================] - 1s 2ms/step - loss: 22279.1758
# Epoch 12/50
# 548/548 [==============================] - 1s 2ms/step - loss: 21370.6660
# Epoch 13/50
# 548/548 [==============================] - 1s 2ms/step - loss: 20710.6777
# Epoch 14/50
# 548/548 [==============================] - 1s 2ms/step - loss: 20054.2031
# Epoch 15/50
# 548/548 [==============================] - 1s 2ms/step - loss: 19311.1660
# Epoch 16/50
# 548/548 [==============================] - 1s 2ms/step - loss: 18760.4238
# Epoch 17/50
# 548/548 [==============================] - 1s 2ms/step - loss: 18159.3867
# Epoch 18/50
# 548/548 [==============================] - 1s 2ms/step - loss: 17912.7891
# Epoch 19/50
# 548/548 [==============================] - 1s 2ms/step - loss: 17575.0566
# Epoch 20/50
# 548/548 [==============================] - 1s 2ms/step - loss: 17122.2402
# Epoch 21/50
# 548/548 [==============================] - 1s 2ms/step - loss: 16667.9258
# Epoch 22/50
# 548/548 [==============================] - 1s 2ms/step - loss: 16223.3848
# Epoch 23/50
# 548/548 [==============================] - 1s 2ms/step - loss: 16129.7148
# Epoch 24/50
# 548/548 [==============================] - 1s 2ms/step - loss: 16006.9912
# Epoch 25/50
# 548/548 [==============================] - 1s 2ms/step - loss: 15857.4561
# Epoch 26/50
# 548/548 [==============================] - 1s 2ms/step - loss: 15229.8330
# Epoch 27/50
# 548/548 [==============================] - 1s 2ms/step - loss: 14518.1572
# Epoch 28/50
# 548/548 [==============================] - 1s 2ms/step - loss: 14186.1611
# Epoch 29/50
# 548/548 [==============================] - 1s 2ms/step - loss: 13404.5586
# Epoch 30/50
# 548/548 [==============================] - 1s 2ms/step - loss: 13602.8584
# Epoch 31/50
# 548/548 [==============================] - 1s 2ms/step - loss: 13022.0928
# Epoch 32/50
# 548/548 [==============================] - 1s 2ms/step - loss: 12877.1025
# Epoch 33/50
# 548/548 [==============================] - 1s 2ms/step - loss: 13028.0596
# Epoch 34/50
# 548/548 [==============================] - 1s 2ms/step - loss: 13030.0781
# Epoch 35/50
# 548/548 [==============================] - 1s 2ms/step - loss: 12731.7578
# Epoch 36/50
# 548/548 [==============================] - 1s 2ms/step - loss: 12918.8555
# Epoch 37/50
# 548/548 [==============================] - 1s 2ms/step - loss: 12404.7168
# Epoch 38/50
# 548/548 [==============================] - 1s 2ms/step - loss: 12683.5322
# Epoch 39/50
# 548/548 [==============================] - 1s 2ms/step - loss: 12451.3330
# Epoch 40/50
# 548/548 [==============================] - 1s 2ms/step - loss: 12435.4473
# Epoch 41/50
# 548/548 [==============================] - 1s 2ms/step - loss: 12386.3408
# Epoch 42/50
# 548/548 [==============================] - 1s 2ms/step - loss: 12340.1895
# Epoch 43/50
# 548/548 [==============================] - 1s 2ms/step - loss: 12364.8555
# Epoch 44/50
# 548/548 [==============================] - 1s 2ms/step - loss: 12394.5029
# Epoch 45/50
# 548/548 [==============================] - 1s 2ms/step - loss: 12191.2949
# Epoch 46/50
# 548/548 [==============================] - 1s 2ms/step - loss: 12055.2217
# Epoch 47/50
# 548/548 [==============================] - 1s 2ms/step - loss: 12250.4512
# Epoch 48/50
# 548/548 [==============================] - 1s 2ms/step - loss: 11954.5088
# Epoch 49/50
# 548/548 [==============================] - 1s 2ms/step - loss: 12083.3916
# Epoch 50/50
# 548/548 [==============================] - 1s 2ms/step - loss: 12144.5371
# 273/273 [==============================] - 1s 1ms/step
# Mean Absolute Error: 74.26218959363236
# Mean Squared Error: 10887.26604100416
# Mean Absolute Percentage Error: 2.25 %
# Score: 0.9637458924948186

# %% [markdown]
# # Model evaluation

# %%
results_df = pd.DataFrame.from_dict(data=results, columns=['Score', 'MAE', 'MSE', 'MAPE'], orient='index')
results_df.sort_values(by='Score', ascending=False, inplace=True)
results_df
# Out:
#                          Score         MAE           MSE    MAPE
# Random forest-MS      0.993577   30.915104   1902.739903  0.0092
# Random forest         0.993429   31.229791   1946.568806  0.0093
# XGBoost               0.992477   34.972437   2228.600566  0.0105
# XGBoost-MS            0.992477   34.972437   2228.600566  0.0105
# AR                    0.992467   34.780692   2467.691861  0.0106
# LSTM                  0.984645   53.176068   4548.843284  0.0162
# Neural Network-MS     0.983424   52.672893   4910.598910  0.0160
# Neural Network        0.982784   56.950250   5099.921282  0.0176
# Decision Tree-MS      0.980942   52.101315   5645.812762  0.0156
# Decision Tree         0.980887   52.233880   5662.049843  0.0157
# GRU-MS                0.963746   74.262190  10887.266041  0.0225
# LSTM-MS               0.954625   85.208497  13626.203494  0.0261
# GRU                   0.940134  122.517702  17734.608080  0.0381
# Naive Baseline Model  0.910382  119.747672  26548.353527  0.0374
